# %% [markdown]
# # **STATISTICS BASICS THEORY QUESTIONS**

# %% [markdown]
# # 1. WHAT IS STATISTICS, AND WHY IS IT IMPORTANT?
#
#    * STATISTICS IS THE SCIENCE OF COLLECTING, ANALYZING, INTERPRETING, AND PRESENTING DATA. IT HELPS US UNDERSTAND PATTERNS, RELATIONSHIPS, AND TRENDS IN DATA, MAKING IT A CRITICAL TOOL FOR DECISION-MAKING IN FIELDS LIKE BUSINESS, HEALTHCARE, ECONOMICS, AND SOCIAL SCIENCES. BY APPLYING STATISTICAL METHODS, WE CAN MAKE DATA-DRIVEN PREDICTIONS AND INFORM POLICY OR STRATEGY.
#
# # 2. WHAT ARE THE TWO MAIN TYPES OF STATISTICS?
#
#    * THE TWO MAIN TYPES OF STATISTICS ARE:
#
#      * **DESCRIPTIVE STATISTICS**: SUMMARIZES AND ORGANIZES DATA TO DESCRIBE ITS MAIN FEATURES (E.G., AVERAGES, RANGES).
#      * **INFERENTIAL STATISTICS**: MAKES PREDICTIONS OR INFERENCES ABOUT A POPULATION BASED ON A SAMPLE, OFTEN USING PROBABILITY AND HYPOTHESIS TESTING.
#
# # 3. WHAT ARE DESCRIPTIVE STATISTICS?
#
#    * DESCRIPTIVE STATISTICS INVOLVES SUMMARIZING OR DESCRIBING THE BASIC FEATURES OF A DATASET. THIS INCLUDES MEASURES LIKE **CENTRAL TENDENCY** (MEAN, MEDIAN, MODE), **DISPERSION** (VARIANCE, STANDARD DEVIATION, RANGE), AND **SHAPE** (SKEWNESS, KURTOSIS) TO PROVIDE A CLEAR SNAPSHOT OF THE DATA.
#
# # 4. WHAT IS INFERENTIAL STATISTICS?
#
#    * INFERENTIAL STATISTICS GOES BEYOND THE DATA AT HAND TO DRAW CONCLUSIONS ABOUT A LARGER POPULATION. IT INVOLVES **HYPOTHESIS TESTING**, **CONFIDENCE INTERVALS**, AND **REGRESSION ANALYSIS** TO MAKE PREDICTIONS OR TEST THEORIES BASED ON SAMPLE DATA.
#
# # 5. WHAT IS SAMPLING IN STATISTICS?
#
#    * SAMPLING IS THE PROCESS OF SELECTING A SUBSET OF INDIVIDUALS OR ITEMS FROM A LARGER POPULATION TO ESTIMATE CHARACTERISTICS OF THE ENTIRE POPULATION. SINCE STUDYING THE ENTIRE POPULATION IS OFTEN IMPRACTICAL, SAMPLING ALLOWS US TO GATHER INSIGHTS AND MAKE GENERALIZATIONS WITH A SMALLER GROUP.
#
# # 6. WHAT ARE THE DIFFERENT TYPES OF SAMPLING METHODS?
#
#    * COMMON SAMPLING METHODS INCLUDE:
#
#      * **SIMPLE RANDOM SAMPLING**: EVERY INDIVIDUAL HAS AN EQUAL CHANCE OF BEING SELECTED.
#      * **SYSTEMATIC SAMPLING**: EVERY NTH INDIVIDUAL IS SELECTED FROM A LIST.
#      * **STRATIFIED SAMPLING**: THE POPULATION IS DIVIDED INTO SUBGROUPS (STRATA), AND SAMPLES ARE TAKEN FROM EACH.
#      * **CLUSTER SAMPLING**: THE POPULATION IS DIVIDED INTO CLUSTERS, AND ENTIRE CLUSTERS ARE SELECTED RANDOMLY.
#
# # 7. WHAT IS THE DIFFERENCE BETWEEN RANDOM AND NON-RANDOM SAMPLING?
#
#    * **RANDOM SAMPLING** ELIMINATES BIAS BY GIVING EACH MEMBER OF THE POPULATION AN EQUAL CHANCE OF BEING CHOSEN, ENSURING THE SAMPLE IS REPRESENTATIVE. **NON-RANDOM SAMPLING**, SUCH AS CONVENIENCE OR JUDGMENT SAMPLING, INVOLVES CHOOSING INDIVIDUALS BASED ON SPECIFIC CRITERIA, WHICH MAY INTRODUCE BIAS AND AFFECT THE GENERALIZABILITY OF RESULTS.
#
# # 8. DEFINE AND GIVE EXAMPLES OF QUALITATIVE AND QUANTITATIVE DATA.
#
#    * **QUALITATIVE DATA** (ALSO CALLED CATEGORICAL): DESCRIBES ATTRIBUTES OR QUALITIES. EXAMPLES INCLUDE COLORS (E.G., RED, BLUE), TYPES OF ANIMALS (E.G., CATS, DOGS), OR PREFERENCES (E.G., YES/NO RESPONSES).
#    * **QUANTITATIVE DATA** (ALSO CALLED NUMERICAL): REPRESENTS AMOUNTS OR COUNTS. EXAMPLES INCLUDE AGE (E.G., 25 YEARS), HEIGHT (E.G., 180 CM), OR INCOME (E.G., \$50,000).
#
# # 9. WHAT ARE THE DIFFERENT TYPES OF DATA IN STATISTICS?
#
#    * **NOMINAL**: CATEGORIES WITH NO ORDER (E.G., GENDER, HAIR COLOR).
#    * **ORDINAL**: CATEGORIES WITH A MEANINGFUL ORDER BUT NO CONSISTENT INTERVALS (E.G., RANKING IN A COMPETITION).
#    * **INTERVAL**: NUMERICAL DATA WITH EQUAL INTERVALS BUT NO TRUE ZERO (E.G., TEMPERATURE IN CELSIUS).
#    * **RATIO**: NUMERICAL DATA WITH BOTH EQUAL INTERVALS AND A TRUE ZERO POINT (E.G., WEIGHT, HEIGHT, AGE).
#
# # 10. EXPLAIN NOMINAL, ORDINAL, INTERVAL, AND RATIO LEVELS OF MEASUREMENT.
#
# * **NOMINAL**: DATA CATEGORIZED WITHOUT ANY ORDER OR RANKING (E.G., TYPES OF FRUITS: APPLE, ORANGE, BANANA).
# * **ORDINAL**: DATA WITH AN INHERENT ORDER BUT UNKNOWN DISTANCES BETWEEN CATEGORIES (E.G., SATISFACTION LEVELS: POOR, FAIR, GOOD).
# * **INTERVAL**: DATA WITH ORDERED CATEGORIES AND EQUAL INTERVALS, BUT NO TRUE ZERO (E.G., CALENDAR YEARS, TEMPERATURE IN CELSIUS).
# * **RATIO**: SIMILAR TO INTERVAL DATA, BUT WITH A TRUE ZERO POINT, ALLOWING FOR MEANINGFUL RATIOS (E.G., WEIGHT, INCOME, AGE).
#
# # 11. WHAT IS THE MEASURE OF CENTRAL TENDENCY?
#
# * MEASURES OF CENTRAL TENDENCY ARE STATISTICAL VALUES THAT DESCRIBE THE CENTER OF A DATASET. THEY INCLUDE:
#
#   * **MEAN**: THE ARITHMETIC AVERAGE OF THE DATA.
#   * **MEDIAN**: THE MIDDLE VALUE WHEN DATA IS ORDERED.
#   * **MODE**: THE MOST FREQUENT VALUE IN THE DATASET.
#
# # 12. DEFINE MEAN, MEDIAN, AND MODE.
#
# * **MEAN**: THE SUM OF ALL DATA POINTS DIVIDED BY THE NUMBER OF POINTS. IT IS SENSITIVE TO EXTREME VALUES (OUTLIERS).
# * **MEDIAN**: THE MIDDLE VALUE WHEN THE DATA IS SORTED IN ASCENDING OR DESCENDING ORDER. IT’S USEFUL WHEN DATA HAS OUTLIERS, AS IT ISN’T AS AFFECTED BY THEM.
# * **MODE**: THE VALUE THAT APPEARS MOST FREQUENTLY IN A DATASET. THERE CAN BE MULTIPLE MODES OR NO MODE AT ALL.
#
# # 13. WHAT IS THE SIGNIFICANCE OF THE MEASURE OF CENTRAL TENDENCY?
#
# * THESE MEASURES GIVE US A SUMMARY OF THE DATA AND A WAY TO DESCRIBE THE "CENTER" OR TYPICAL VALUE OF A DATASET. THEY HELP TO UNDERSTAND GENERAL TRENDS AND MAKE COMPARISONS BETWEEN DIFFERENT DATASETS.
#
# # 14. WHAT IS VARIANCE, AND HOW IS IT CALCULATED?
#
# * VARIANCE MEASURES HOW FAR THE DATA POINTS ARE FROM THE MEAN. IT’S CALCULATED BY AVERAGING THE SQUARED DIFFERENCES FROM THE MEAN. A HIGHER VARIANCE INDICATES GREATER SPREAD IN THE DATA.
#
# # 15. WHAT IS STANDARD DEVIATION, AND WHY IS IT IMPORTANT?
#
# * STANDARD DEVIATION IS THE SQUARE ROOT OF VARIANCE, PROVIDING A MEASURE OF HOW SPREAD OUT THE VALUES ARE IN A DATASET. IT'S IMPORTANT BECAUSE IT GIVES A MORE INTUITIVE UNDERSTANDING OF DATA VARIABILITY, AS IT'S IN THE SAME UNITS AS THE DATA ITSELF.
#
# # 16. DEFINE AND EXPLAIN THE TERM RANGE IN STATISTICS.
#
# * RANGE IS THE DIFFERENCE BETWEEN THE HIGHEST AND LOWEST VALUES IN A DATASET. IT’S A SIMPLE WAY TO GAUGE THE SPREAD OF THE DATA, BUT IT’S SENSITIVE TO OUTLIERS.
#
# # 17. WHAT IS THE DIFFERENCE BETWEEN VARIANCE AND STANDARD DEVIATION?
#
# * **VARIANCE** MEASURES THE AVERAGE SQUARED DEVIATIONS FROM THE MEAN, AND IS IN SQUARED UNITS. **STANDARD DEVIATION** IS THE SQUARE ROOT OF VARIANCE AND IS IN THE SAME UNITS AS THE DATA, MAKING IT MORE INTERPRETABLE.
#
# # 18. WHAT IS SKEWNESS IN A DATASET?
#
# * SKEWNESS REFERS TO THE ASYMMETRY OF A DISTRIBUTION. IF A DATASET HAS A LONG TAIL ON ONE SIDE, IT'S SKEWED. A POSITIVE SKEW MEANS THE TAIL IS ON THE RIGHT; A NEGATIVE SKEW MEANS THE TAIL IS ON THE LEFT.
#
# # 19. WHAT DOES IT MEAN IF A DATASET IS POSITIVELY OR NEGATIVELY SKEWED?
#
# * **POSITIVELY SKEWED**: THE RIGHT TAIL IS LONGER, AND THE DATA ARE CONCENTRATED ON THE LEFT SIDE OF THE MEAN.
# * **NEGATIVELY SKEWED**: THE LEFT TAIL IS LONGER, AND THE DATA ARE CONCENTRATED ON THE RIGHT SIDE OF THE MEAN.
#
# # 20. DEFINE AND EXPLAIN KURTOSIS.
#
# * KURTOSIS MEASURES THE "PEAKEDNESS" OR "FLATNESS" OF A DISTRIBUTION. HIGH KURTOSIS INDICATES A DISTRIBUTION WITH HEAVY TAILS OR OUTLIERS (LEPTOKURTIC), WHILE LOW KURTOSIS SUGGESTS A FLATTER DISTRIBUTION (PLATYKURTIC).
#
# # 21. WHAT IS THE PURPOSE OF COVARIANCE?
#
# * COVARIANCE MEASURES HOW TWO VARIABLES CHANGE TOGETHER. IT’S USED TO ASSESS THE DIRECTION OF THE RELATIONSHIP BETWEEN TWO VARIABLES—WHETHER THEY MOVE IN THE SAME DIRECTION (POSITIVE COVARIANCE) OR OPPOSITE DIRECTIONS (NEGATIVE COVARIANCE).
#
# # 22. WHAT DOES CORRELATION MEASURE IN STATISTICS?
#
# * CORRELATION MEASURES THE STRENGTH AND DIRECTION OF A LINEAR RELATIONSHIP BETWEEN TWO VARIABLES. IT’S STANDARDIZED BETWEEN -1 (PERFECT NEGATIVE CORRELATION) AND +1 (PERFECT POSITIVE CORRELATION), WITH 0 MEANING NO LINEAR RELATIONSHIP.
#
# # 23. WHAT IS THE DIFFERENCE BETWEEN COVARIANCE AND CORRELATION?
#
# * **COVARIANCE** SHOWS THE DIRECTION OF THE RELATIONSHIP BETWEEN TWO VARIABLES BUT IS SENSITIVE TO THE SCALE OF THE DATA, MAKING IT HARD TO INTERPRET DIRECTLY. **CORRELATION** STANDARDIZES THIS RELATIONSHIP, MAKING IT MORE USEFUL FOR COMPARING RELATIONSHIPS ACROSS DIFFERENT DATASETS.
#
# # 24. WHAT ARE SOME REAL-WORLD APPLICATIONS OF STATISTICS?
#
# * STATISTICS ARE WIDELY USED:
#
#   * **HEALTHCARE**: TO ANALYZE CLINICAL TRIAL DATA, MEASURE DRUG EFFECTIVENESS, OR PREDICT DISEASE OUTBREAKS.
#   * **BUSINESS**: FOR MARKET RESEARCH, CUSTOMER SATISFACTION ANALYSIS, AND FINANCIAL FORECASTING.
#   * **SPORTS**: TO TRACK PLAYER PERFORMANCE, MAKE TEAM DECISIONS, AND PREDICT GAME OUTCOMES.
#   * **GOVERNMENT**: FOR POLLING, ECONOMIC INDICATORS, AND POLICY-MAKING BASED ON DATA ANALYSIS.

# %% [markdown]
# # **STATISTICS BASICS PRACTICAL QUESTIONS**

# %% [markdown]
# # 1. HOW DO YOU CALCULATE THE MEAN, MEDIAN, AND MODE OF A DATASET?

# %%
IMPORT STATISTICS

DEF CALCULATE_STATISTICS(DATA):
    # CALCULATE MEAN
    MEAN = SUM(DATA) / LEN(DATA)

    # CALCULATE MEDIAN
    MEDIAN = STATISTICS.MEDIAN(DATA)

    # CALCULATE MODE
    TRY:
        MODE = STATISTICS.MODE(DATA)
    EXCEPT STATISTICS.STATISTICSERROR:
        MODE = "NO UNIQUE MODE"

    RETURN MEAN, MEDIAN, MODE

# EXAMPLE DATASET
DATA = [5, 8, 12, 16, 20]

# CALCULATE AND PRINT THE STATISTICS
MEAN, MEDIAN, MODE = CALCULATE_STATISTICS(DATA)

PRINT("MEAN:", MEAN)
PRINT("MEDIAN:", MEDIAN)
PRINT("MODE:", MODE)
# Out:
# Mean: 12.2
# Median: 12
# Mode: 5

# %% [markdown]
# # 2. WRITE A PYTHON PROGRAM TO COMPUTE THE VARIANCE AND STANDARD DEVIATION OF A DATASET.

# %%
IMPORT MATH

DEF CALCULATE_VARIANCE_AND_STD(DATA):
    # CALCULATE MEAN
    MEAN = SUM(DATA) / LEN(DATA)

    # CALCULATE VARIANCE
    VARIANCE = SUM((X - MEAN) ** 2 FOR X IN DATA) / LEN(DATA)

    # CALCULATE STANDARD DEVIATION
    STD_DEVIATION = MATH.SQRT(VARIANCE)

    RETURN VARIANCE, STD_DEVIATION

# EXAMPLE DATASET
DATA = [5, 8, 12, 16, 20]

# CALCULATE AND PRINT THE VARIANCE AND STANDARD DEVIATION
VARIANCE, STD_DEVIATION = CALCULATE_VARIANCE_AND_STD(DATA)

PRINT("VARIANCE:", VARIANCE)
PRINT("STANDARD DEVIATION:", STD_DEVIATION)
# Out:
# Variance: 28.96
# Standard Deviation: 5.3814496188294845

# %% [markdown]
# # 3.CREATE A DATASET AND CLASSIFY IT INTO NOMINAL, ORDINAL, INTERVAL, AND RATIO TYPES.

# %%
# NOMINAL: CATEGORIES WITH NO ORDER
ANIMALS = ['DOG', 'CAT', 'BIRD', 'FISH', 'DOG']

# ORDINAL: CATEGORIES WITH MEANINGFUL ORDER, BUT NO CONSISTENT INTERVALS
EDUCATION_LEVELS = ['HIGH SCHOOL', 'BACHELOR', 'MASTER', 'PHD']

# INTERVAL: NUMERICAL DATA WITH MEANINGFUL INTERVALS BUT NO TRUE ZERO
TEMPERATURES_CELSIUS = [10, 20, 30, 40, 50]

# RATIO: NUMERICAL DATA WITH A TRUE ZERO POINT
AGES = [20, 25, 30, 35, 40]

# DISPLAYING THE DATASET
PRINT("NOMINAL DATA (ANIMAL TYPES):", ANIMALS)
PRINT("ORDINAL DATA (EDUCATION LEVELS):", EDUCATION_LEVELS)
PRINT("INTERVAL DATA (TEMPERATURES IN CELSIUS):", TEMPERATURES_CELSIUS)
PRINT("RATIO DATA (AGES):", AGES)
# Out:
# Nominal Data (Animal Types): ['Dog', 'Cat', 'Bird', 'Fish', 'Dog']
# Ordinal Data (Education Levels): ['High School', 'Bachelor', 'Master', 'PhD']
# Interval Data (Temperatures in Celsius): [10, 20, 30, 40, 50]
# Ratio Data (Ages): [20, 25, 30, 35, 40]

# %% [markdown]
# # 4. IMPLEMENT SAMPLING TECHNIQUES LIKE RANDOM SAMPLING AND STRATIFIED SAMPLING.

# %%
IMPORT RANDOM
IMPORT PANDAS AS PD

# EXAMPLE POPULATION DATASET
POPULATION_DATA = {
    'AGE': [22, 25, 27, 30, 35, 40, 45, 50, 55, 60],
    'GENDER': ['MALE', 'FEMALE', 'MALE', 'FEMALE', 'MALE', 'FEMALE', 'MALE', 'FEMALE', 'MALE', 'FEMALE'],
    'INCOME': [50000, 55000, 60000, 65000, 70000, 75000, 80000, 85000, 90000, 95000]
}

# CONVERT THE DATASET TO A PANDAS DATAFRAME
POPULATION_DF = PD.DATAFRAME(POPULATION_DATA)

# 1. RANDOM SAMPLING
DEF RANDOM_SAMPLING(DATA, SAMPLE_SIZE):
    RETURN DATA.SAMPLE(N=SAMPLE_SIZE, RANDOM_STATE=42)

# 2. STRATIFIED SAMPLING
DEF STRATIFIED_SAMPLING(DATA, STRATIFY_COLUMN, SAMPLE_SIZE):
    STRATIFIED_SAMPLE = DATA.GROUPBY(STRATIFY_COLUMN).APPLY(LAMBDA X: X.SAMPLE(N=INT(SAMPLE_SIZE / LEN(DATA[STRATIFY_COLUMN].UNIQUE())), RANDOM_STATE=42)).RESET_INDEX(DROP=TRUE)
    RETURN STRATIFIED_SAMPLE

# EXAMPLE: RANDOM SAMPLING
SAMPLE_SIZE = 4
RANDOM_SAMPLE = RANDOM_SAMPLING(POPULATION_DF, SAMPLE_SIZE)

# EXAMPLE: STRATIFIED SAMPLING (STRATIFIED BY 'GENDER')
STRATIFIED_SAMPLE = STRATIFIED_SAMPLING(POPULATION_DF, STRATIFY_COLUMN='GENDER', SAMPLE_SIZE=4)

# DISPLAYING THE RESULTS
PRINT("RANDOM SAMPLE:")
PRINT(RANDOM_SAMPLE)
PRINT("\NSTRATIFIED SAMPLE (BASED ON GENDER):")
PRINT(STRATIFIED_SAMPLE)
# Out:
# Random Sample:
#    Age  Gender  Income
# 8   55    Male   90000
# 1   25  Female   55000
# 5   40  Female   75000
# 0   22    Male   50000
#
# Stratified Sample (based on Gender):
#    Age  Gender  Income
# 0   30  Female   65000
# 1   60  Female   95000
# 2   27    Male   60000
# 3   55    Male   90000
# <ipython-input-5-1105890586>:20: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   stratified_sample = data.groupby(stratify_column).apply(lambda x: x.sample(n=int(sample_size / len(data[stratify_column].unique())), random_state=42)).reset_index(drop=True)

# %% [markdown]
# # 5. WRITE A PYTHON FUNCTION TO CALCULATE THE RANGE OF A DATASET.

# %%
DEF CALCULATE_RANGE(DATA):
    # CALCULATE THE RANGE (MAX - MIN)
    DATA_RANGE = MAX(DATA) - MIN(DATA)
    RETURN DATA_RANGE

# EXAMPLE DATASET
DATA = [5, 8, 12, 16, 20]

# CALCULATE AND PRINT THE RANGE
RANGE_VALUE = CALCULATE_RANGE(DATA)

PRINT("RANGE OF THE DATASET:", RANGE_VALUE)
# Out:
# Range of the dataset: 15

# %% [markdown]
# # 6. CREATE A DATASET AND PLOT ITS HISTOGRAM TO VISUALIZE SKEWNESS.

# %%
IMPORT MATPLOTLIB.PYPLOT AS PLT
IMPORT NUMPY AS NP

# CREATE A DATASET (FOR EXAMPLE, A RIGHT-SKEWED DATASET)
DATA = NP.RANDOM.LOGNORMAL(MEAN=0, SIGMA=1, SIZE=1000)

# PLOTTING THE HISTOGRAM
PLT.HIST(DATA, BINS=30, EDGECOLOR='BLACK', ALPHA=0.7)
PLT.TITLE('HISTOGRAM OF RIGHT-SKEWED DATA')
PLT.XLABEL('VALUE')
PLT.YLABEL('FREQUENCY')
PLT.SHOW()

# %% [markdown]
# # CALCULATE SKEWNESS AND KURTOSIS OF A DATASET USING PYTHON LIBRARIES.

# %%
FROM SCIPY.STATS IMPORT SKEW, KURTOSIS
IMPORT NUMPY AS NP

# CREATE A DATASET (E.G., NORMAL DISTRIBUTION)
DATA = NP.RANDOM.NORMAL(0, 1, 1000)

# CALCULATE SKEWNESS AND KURTOSIS
DATA_SKEWNESS = SKEW(DATA)
DATA_KURTOSIS = KURTOSIS(DATA)

PRINT(F"SKEWNESS: {DATA_SKEWNESS}")
PRINT(F"KURTOSIS: {DATA_KURTOSIS}")
# Out:
# Skewness: 0.08291883107479019
# Kurtosis: 0.03517697039429013

# %% [markdown]
# # 8. GENERATE A DATASET AND DEMONSTRATE POSITIVE AND NEGATIVE SKEWNESS.

# %%
IMPORT MATPLOTLIB.PYPLOT AS PLT
IMPORT NUMPY AS NP

# POSITIVE SKEW (RIGHT-SKEWED)
DATA_POSITIVE_SKEW = NP.RANDOM.LOGNORMAL(MEAN=0, SIGMA=1, SIZE=1000)

# NEGATIVE SKEW (LEFT-SKEWED)
DATA_NEGATIVE_SKEW = NP.RANDOM.LOGNORMAL(MEAN=0, SIGMA=1, SIZE=1000) ** -1

# PLOTTING THE DATASETS
FIG, AX = PLT.SUBPLOTS(1, 2, FIGSIZE=(12, 6))

# POSITIVE SKEW
AX[0].HIST(DATA_POSITIVE_SKEW, BINS=30, EDGECOLOR='BLACK', ALPHA=0.7)
AX[0].SET_TITLE('POSITIVE SKEW (RIGHT SKEWED)')

# NEGATIVE SKEW
AX[1].HIST(DATA_NEGATIVE_SKEW, BINS=30, EDGECOLOR='BLACK', ALPHA=0.7)
AX[1].SET_TITLE('NEGATIVE SKEW (LEFT SKEWED)')

PLT.TIGHT_LAYOUT()
PLT.SHOW()

# %% [markdown]
# # 9. WRITE A PYTHON SCRIPT TO CALCULATE COVARIANCE BETWEEN TWO DATASETS.

# %%
IMPORT NUMPY AS NP

# CREATE TWO DATASETS
X = NP.RANDOM.NORMAL(0, 1, 1000)
Y = NP.RANDOM.NORMAL(0, 1, 1000)

# CALCULATE COVARIANCE
COV_MATRIX = NP.COV(X, Y)
COVARIANCE = COV_MATRIX[0, 1]  # COVARIANCE IS IN THE [0,1] POSITION OF THE MATRIX

PRINT(F"COVARIANCE BETWEEN X AND Y: {COVARIANCE}")
# Out:
# Covariance between x and y: -0.03607279444324317

# %% [markdown]
# # 10. WRITE A PYTHON SCRIPT TO CALCULATE THE CORRELATION COEFFICIENT BETWEEN TWO DATASETS.

# %%
IMPORT NUMPY AS NP

# CREATE TWO DATASETS
X = NP.RANDOM.NORMAL(0, 1, 1000)
Y = NP.RANDOM.NORMAL(0, 1, 1000)

# CALCULATE CORRELATION COEFFICIENT
CORRELATION_MATRIX = NP.CORRCOEF(X, Y)
CORRELATION_COEFFICIENT = CORRELATION_MATRIX[0, 1]

PRINT(F"CORRELATION COEFFICIENT BETWEEN X AND Y: {CORRELATION_COEFFICIENT}")
# Out:
# Correlation coefficient between x and y: -0.06704123714104472

# %% [markdown]
# # 11. CREATE A SCATTER PLOT TO VISUALIZE THE RELATIONSHIP BETWEEN TWO VARIABLES.

# %%
IMPORT MATPLOTLIB.PYPLOT AS PLT

# SAMPLE DATA
X = [5, 7, 8, 7, 2, 17, 2, 9, 4, 11]
Y = [99, 86, 87, 88, 100, 86, 103, 87, 94, 78]

# CREATE SCATTER PLOT
PLT.SCATTER(X, Y, COLOR='BLUE', MARKER='O')

# ADD TITLES AND LABELS
PLT.TITLE("SCATTER PLOT: RELATIONSHIP BETWEEN X AND Y")
PLT.XLABEL("VARIABLE X")
PLT.YLABEL("VARIABLE Y")

# SHOW GRID
PLT.GRID(TRUE)

# SHOW PLOT
PLT.SHOW()

# %% [markdown]
# # 12. IMPLEMENT AND COMPARE SIMPLE RANDOM SAMPLING AND SYSTEMATIC SAMPLING.

# %%
IMPORT NUMPY AS NP

# CREATE A DATASET
POPULATION = NP.ARANGE(1, 101)

# SIMPLE RANDOM SAMPLING
RANDOM_SAMPLE = NP.RANDOM.CHOICE(POPULATION, 10, REPLACE=FALSE)

# SYSTEMATIC SAMPLING
K = 10  # INTERVAL
SYSTEMATIC_SAMPLE = POPULATION[::K][:10]

PRINT("RANDOM SAMPLE:", RANDOM_SAMPLE)
PRINT("SYSTEMATIC SAMPLE:", SYSTEMATIC_SAMPLE)
# Out:
# Random Sample: [34 24  7 21 36 14 15 67 80  4]
# Systematic Sample: [ 1 11 21 31 41 51 61 71 81 91]

# %% [markdown]
# # 13. CALCULATE THE MEAN, MEDIAN, AND MODE OF GROUPED DATA.

# %%
IMPORT PANDAS AS PD

# GROUPED DATA: AGE INTERVALS AND FREQUENCY
DATA = {
    'AGE INTERVAL': ['0-10', '11-20', '21-30', '31-40'],
    'FREQUENCY': [5, 8, 12, 7]
}

# CREATE A DATAFRAME
DF = PD.DATAFRAME(DATA)

# CALCULATE MIDPOINTS OF INTERVALS
DF['MIDPOINT'] = [(INT(X.SPLIT('-')[0]) + INT(X.SPLIT('-')[1])) / 2 FOR X IN DF['AGE INTERVAL']]

# CALCULATE MEAN, MEDIAN, AND MODE
MEAN = (DF['MIDPOINT'] * DF['FREQUENCY']).SUM() / DF['FREQUENCY'].SUM()

# CALCULATE THE CUMULATIVE FREQUENCY
CUMULATIVE_FREQUENCY = DF['FREQUENCY'].CUMSUM()

# FIND THE MIDPOINT WHERE THE CUMULATIVE FREQUENCY FIRST EXCEEDS HALF OF THE TOTAL FREQUENCY
# THIS IS THE MEDIAN FOR GROUPED DATA
MEDIAN_INDEX = (CUMULATIVE_FREQUENCY >= DF['FREQUENCY'].SUM() / 2).IDXMAX()
MEDIAN = DF['MIDPOINT'].LOC[MEDIAN_INDEX]

# CALCULATE MODE - MIDPOINT OF THE INTERVAL WITH THE HIGHEST FREQUENCY
MODE = DF['MIDPOINT'].ILOC[DF['FREQUENCY'].IDXMAX()]

PRINT(F"MEAN: {MEAN}")
PRINT(F"MEDIAN: {MEDIAN}")
PRINT(F"MODE: {MODE}")
# Out:
# Mean: 21.984375
# Median: 25.5
# Mode: 25.5

# %% [markdown]
# # 14. SIMULATE DATA USING PYTHON AND CALCULATE ITS CENTRAL TENDENCY AND DISPERSION.

# %%
IMPORT NUMPY AS NP
IMPORT PANDAS AS PD

# SIMULATING A DATASET OF 1000 DATA POINTS
DATA = NP.RANDOM.NORMAL(50, 10, 1000)

# CENTRAL TENDENCY
MEAN = NP.MEAN(DATA)
MEDIAN = NP.MEDIAN(DATA)
MODE = PD.SERIES(DATA).MODE()[0]

# DISPERSION
VARIANCE = NP.VAR(DATA)
STD_DEV = NP.STD(DATA)
RANGE_VALUE = NP.PTP(DATA)

PRINT(F"MEAN: {MEAN}")
PRINT(F"MEDIAN: {MEDIAN}")
PRINT(F"MODE: {MODE}")
PRINT(F"VARIANCE: {VARIANCE}")
PRINT(F"STANDARD DEVIATION: {STD_DEV}")
PRINT(F"RANGE: {RANGE_VALUE}")
# Out:
# Mean: 49.747572905118076
# Median: 49.88515821891597
# Mode: 16.609368976847477
# Variance: 95.15132984454242
# Standard Deviation: 9.754554312962865
# Range: 65.20438238573546

# %% [markdown]
# # 15. USE NUMPY OR PANDAS TO SUMMARIZE A DATASET'S DESCRIPTIVE STATISTICS.

# %%
IMPORT PANDAS AS PD
IMPORT NUMPY AS NP

# CREATE A SAMPLE DATASET
DATA = NP.RANDOM.NORMAL(50, 10, 1000)

# CONVERT TO A PANDAS DATAFRAME
DF = PD.DATAFRAME(DATA, COLUMNS=['VALUES'])

# SUMMARIZE DESCRIPTIVE STATISTICS
SUMMARY = DF.DESCRIBE()
PRINT(SUMMARY)
# Out:
#             Values
# count  1000.000000
# mean     49.854574
# std      10.016774
# min      16.899174
# 25%      43.312823
# 50%      49.431504
# 75%      56.739078
# max      78.112426

# %% [markdown]
# # 16. PLOT A BOXPLOT TO UNDERSTAND THE SPREAD AND IDENTIFY OUTLIERS.

# %%
IMPORT MATPLOTLIB.PYPLOT AS PLT
IMPORT SEABORN AS SNS
IMPORT NUMPY AS NP

# GENERATE A DATASET
DATA = NP.RANDOM.NORMAL(50, 10, 1000)

# CREATE A BOXPLOT
PLT.FIGURE(FIGSIZE=(8, 6))
SNS.BOXPLOT(DATA=DATA)
PLT.TITLE("BOXPLOT OF DATASET")
PLT.SHOW()

# %% [markdown]
# # 17. CALCULATE THE INTERQUARTILE RANGE (IQR) OF A DATASET.

# %%
IMPORT NUMPY AS NP

# GENERATE A DATASET
DATA = NP.RANDOM.NORMAL(50, 10, 1000)

# CALCULATE IQR
Q1 = NP.PERCENTILE(DATA, 25)
Q3 = NP.PERCENTILE(DATA, 75)
IQR = Q3 - Q1

PRINT(F"IQR: {IQR}")
# Out:
# IQR: 13.622923589698566

# %% [markdown]
# # 18. IMPLEMENT Z-SCORE NORMALIZATION AND EXPLAIN ITS SIGNIFICANCE.

# %%
IMPORT NUMPY AS NP

# GENERATE A DATASET
DATA = NP.RANDOM.NORMAL(50, 10, 1000)

# Z-SCORE NORMALIZATION
MEAN = NP.MEAN(DATA)
STD_DEV = NP.STD(DATA)
Z_SCORES = (DATA - MEAN) / STD_DEV

PRINT(F"MEAN: {MEAN}, STANDARD DEVIATION: {STD_DEV}")
PRINT(F"Z-SCORES: {Z_SCORES[:5]}")  # FIRST 5 Z-SCORES
# Out:
# Mean: 50.07443979753186, Standard Deviation: 9.799746217905032
# Z-scores: [ 0.85689767  1.84316046 -0.32378518  0.90669424  1.02932047]

# %% [markdown]
# # 19. COMPARE TWO DATASETS USING THEIR STANDARD DEVIATIONS.

# %%
IMPORT NUMPY AS NP

# GENERATE TWO DATASETS
DATA1 = NP.RANDOM.NORMAL(50, 10, 1000)
DATA2 = NP.RANDOM.NORMAL(60, 5, 1000)

# CALCULATE STANDARD DEVIATION
STD_DEV1 = NP.STD(DATA1)
STD_DEV2 = NP.STD(DATA2)

PRINT(F"STANDARD DEVIATION OF DATA1: {STD_DEV1}")
PRINT(F"STANDARD DEVIATION OF DATA2: {STD_DEV2}")
# Out:
# Standard Deviation of Data1: 10.01442511014657
# Standard Deviation of Data2: 4.901917004319696

# %% [markdown]
# # 20. WRITE A PYTHON PROGRAM TO VISUALIZE COVARIANCE USING A HEATMAP.

# %%
IMPORT SEABORN AS SNS
IMPORT MATPLOTLIB.PYPLOT AS PLT
IMPORT NUMPY AS NP

# GENERATE TWO DATASETS
DATA1 = NP.RANDOM.NORMAL(50, 10, 1000)
DATA2 = NP.RANDOM.NORMAL(60, 5, 1000)

# CREATE A COVARIANCE MATRIX
COV_MATRIX = NP.COV(DATA1, DATA2)

# VISUALIZE COVARIANCE USING A HEATMAP
SNS.HEATMAP(COV_MATRIX, ANNOT=TRUE, CMAP="COOLWARM", XTICKLABELS=["DATA1", "DATA2"], YTICKLABELS=["DATA1", "DATA2"])
PLT.TITLE("COVARIANCE HEATMAP")
PLT.SHOW()

# %% [markdown]
# # 21. USE SEABORN TO CREATE A CORRELATION MATRIX FOR A DATASET.

# %%
IMPORT SEABORN AS SNS
IMPORT MATPLOTLIB.PYPLOT AS PLT
IMPORT PANDAS AS PD

# CREATE A SAMPLE DATAFRAME
DATA = PD.DATAFRAME({
    'A': NP.RANDOM.NORMAL(0, 1, 100),
    'B': NP.RANDOM.NORMAL(1, 2, 100),
    'C': NP.RANDOM.NORMAL(3, 1, 100)
})

# CREATE A CORRELATION MATRIX
CORR_MATRIX = DATA.CORR()

# PLOT THE CORRELATION MATRIX USING SEABORN HEATMAP
SNS.HEATMAP(CORR_MATRIX, ANNOT=TRUE, CMAP='COOLWARM', FMT='.2F', LINEWIDTHS=0.5)
PLT.TITLE("CORRELATION MATRIX")
PLT.SHOW()

# %% [markdown]
# # 22. GENERATE A DATASET AND IMPLEMENT BOTH VARIANCE AND STANDARD DEVIATION COMPUTATIONS.

# %%
IMPORT NUMPY AS NP

# GENERATE A DATASET
DATA = NP.RANDOM.NORMAL(50, 10, 1000)

# VARIANCE AND STANDARD DEVIATION
VARIANCE = NP.VAR(DATA)
STD_DEVIATION = NP.STD(DATA)

PRINT(F"VARIANCE: {VARIANCE}")
PRINT(F"STANDARD DEVIATION: {STD_DEVIATION}")
# Out:
# Variance: 96.69837498078503
# Standard Deviation: 9.833533189082397

# %% [markdown]
# # 23. VISUALIZE SKEWNESS AND KURTOSIS USING PYTHON LIBRARIES LIKE MATPLOTLIB OR SEABORN.

# %%
IMPORT MATPLOTLIB.PYPLOT AS PLT
IMPORT SEABORN AS SNS
IMPORT NUMPY AS NP
FROM SCIPY.STATS IMPORT SKEW, KURTOSIS

# GENERATE A DATASET (RIGHT-SKEWED)
DATA = NP.RANDOM.LOGNORMAL(0, 1, 1000)

# PLOT HISTOGRAM
SNS.HISTPLOT(DATA, KDE=TRUE)
PLT.TITLE(F"SKEWNESS: {SKEW(DATA)} | KURTOSIS: {KURTOSIS(DATA)}")
PLT.SHOW()

# %% [markdown]
# # 24. IMPLEMENT THE PEARSON AND SPEARMAN CORRELATION COEFFICIENTS FOR A DATASET.

# %%
IMPORT NUMPY AS NP
FROM SCIPY.STATS IMPORT PEARSONR, SPEARMANR

# GENERATE TWO DATASETS
X = NP.RANDOM.NORMAL(0, 1, 1000)
Y = NP.RANDOM.NORMAL(0, 1, 1000)

# PEARSON CORRELATION
PEARSON_CORR, _ = PEARSONR(X, Y)

# SPEARMAN CORRELATION
SPEARMAN_CORR, _ = SPEARMANR(X, Y)

PRINT(F"PEARSON CORRELATION: {PEARSON_CORR}")
PRINT(F"SPEARMAN CORRELATION: {SPEARMAN_CORR}")
# Out:
# Pearson Correlation: -0.023831693671886388
# Spearman Correlation: -0.02206167406167406
